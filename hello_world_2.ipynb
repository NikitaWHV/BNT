# %% [markdown]
# # 002 Hello World 2.0

# %%
print("Hello World!")
print("Mein Name ist Nikita Glushko")
print("Ich bin 32 Jahre alt, wohne in Wilhelmshaven und")
print("bin glücklich verheiratet.")
print("Meine Hobbys sind WingTsung, SUP und Reisen.")
print("Gerade arbeite ich als Softwareentwickler in Jever.")
# Out:
# Hello World!
# Mein Name ist Nikita Glushko
# Ich bin 32 Jahre alt, wohne in Wilhelmshaven und
# bin glücklich verheiratet.
# Meine Hobbys sind WingTsung, SUP und Reisen.
# Gerade arbeite ich als Softwareentwickler in Jever.
